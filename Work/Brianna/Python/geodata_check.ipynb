# %% [markdown]
# # checking GeoJSON data

# %%
# dependencies
import json
import pandas as pd

# %% [markdown]
# ### Load GeoJSON data

# %%
# read in json
with open("../../../Data/geojson-counties-fips.json", "r", encoding="utf-8") as f:
    geo_data = json.load(f)

features = geo_data["features"]

# build a list of dicts for each feature with the fields you care about
rows = []
for feature in features:
    # get fips from id
    fips_id = feature.get("id")  # e.g. "01001"
    
    # pulling extra properties
    props = feature.get("properties", {})
    
    rows.append({
        "fips_geo": fips_id, 
        "GEO_ID": props.get("GEO_ID"),
        "STATE": props.get("STATE"),
        "COUNTY": props.get("COUNTY"),
        "NAME": props.get("NAME")
    })

# convert list of dicts to df
geo_df = pd.DataFrame(rows)

# display
geo_df.head()
# Out:
#   fips_geo          GEO_ID STATE COUNTY      NAME
# 0    01001  0500000US01001    01    001   Autauga
# 1    01009  0500000US01009    01    009    Blount
# 2    01017  0500000US01017    01    017  Chambers
# 3    01021  0500000US01021    01    021   Chilton
# 4    01033  0500000US01033    01    033   Colbert

# %% [markdown]
# ### Load county fips data

# %%
# read in counties fips csv
counties_df = pd.read_csv("../../../Data/fips_data.csv", dtype={"FIPS": str})

# display
counties_df.head()
# Out:
#     FIPS           COUNTYNAME STATE
# 0  01000  unidentified county    AL
# 1  01001       Autauga County    AL
# 2  01003       Baldwin County    AL
# 3  01005       Barbour County    AL
# 4  01007          Bibb County    AL

# %% [markdown]
# ### merge df

# %%
# do left merge
merged_df = counties_df.merge(
    geo_df, 
    how="left", 
    left_on="FIPS", 
    right_on="fips_geo",
    indicator=True  # so we can see merge status
)

# %%
# find missing geo fips
merged_df.head()
# Out:
#     FIPS           COUNTYNAME STATE_x fips_geo          GEO_ID STATE_y COUNTY  \
# 0  01000  unidentified county      AL      NaN             NaN     NaN    NaN
# 1  01001       Autauga County      AL    01001  0500000US01001      01    001
# 2  01003       Baldwin County      AL    01003  0500000US01003      01    003
# 3  01005       Barbour County      AL    01005  0500000US01005      01    005
# 4  01007          Bibb County      AL    01007  0500000US01007      01    007
#
#       NAME     _merge
# 0      NaN  left_only
# 1  Autauga       both
# 2  Baldwin       both
# 3  Barbour       both
# 4     Bibb       both

# %%
# create df of unmatched fips
unmatched_fips_df = merged_df[merged_df['_merge'] == 'left_only']
unmatched_fips_df
# Out:
#        FIPS                            COUNTYNAME STATE_x fips_geo GEO_ID  \
# 0     01000                   unidentified county      AL      NaN    NaN
# 68    02000                   unidentified county      AK      NaN    NaN
# 74    02063                   Chugach Census Area      AK      NaN    NaN
# 75    02066              Copper River Census Area      AK      NaN    NaN
# 80    02101  Anchorage Municipality to Bird Creek      AK      NaN    NaN
# ...     ...                                   ...     ...      ...    ...
# 3290  74300                        Midway Islands      UM      NaN    NaN
# 3291  78000                   unidentified county      VI      NaN    NaN
# 3292  78010                      St. Croix Island      VI      NaN    NaN
# 3293  78020                       St. John Island      VI      NaN    NaN
# 3294  78030                     St. Thomas Island      VI      NaN    NaN
#
#      STATE_y COUNTY NAME     _merge
# 0        NaN    NaN  NaN  left_only
# 68       NaN    NaN  NaN  left_only
# 74       NaN    NaN  NaN  left_only
# 75       NaN    NaN  NaN  left_only
# 80       NaN    NaN  NaN  left_only
# ...      ...    ...  ...        ...
# 3290     NaN    NaN  NaN  left_only
# 3291     NaN    NaN  NaN  left_only
# 3292     NaN    NaN  NaN  left_only
# 3293     NaN    NaN  NaN  left_only
# 3294     NaN    NaN  NaN  left_only
#
# [78 rows x 9 columns]

# %%
# show unmatched fips
unmatched_fips = unmatched_fips_df['FIPS'].unique()
unmatched_fips
# Out:
# array(['01000', '02000', '02063', '02066', '02101', '02155', '02158',
#        '02181', '04000', '05000', '06000', '08000', '09000', '10000',
#        '11000', '12000', '13000', '15000', '16000', '17000', '18000',
#        '19000', '20000', '21000', '22000', '23000', '24000', '25000',
#        '26000', '27000', '28000', '29000', '30000', '31000', '32000',
#        '33000', '34000', '35000', '36000', '37000', '38000', '39000',
#        '40000', '41000', '42000', '44000', '45000', '46000', '46102',
#        '47000', '48000', '49000', '50000', '51000', '53000', '54000',
#        '55000', '56000', '60000', '60010', '60020', '60030', '60040',
#        '60050', '66000', '66010', '69000', '69085', '69100', '69110',
#        '69120', '72000', '74000', '74300', '78000', '78010', '78020',
#        '78030'], dtype=object)

# %%
# filter for fips that aren't unknown (don't end in 000)
bad_fips = [fip for fip in unmatched_fips if str(fip).endswith('000') == False]
bad_fips
# Out:
# ['02063',
#  '02066',
#  '02101',
#  '02155',
#  '02158',
#  '02181',
#  '46102',
#  '60010',
#  '60020',
#  '60030',
#  '60040',
#  '60050',
#  '66010',
#  '69085',
#  '69100',
#  '69110',
#  '69120',
#  '74300',
#  '78010',
#  '78020',
#  '78030']
